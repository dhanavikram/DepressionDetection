# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)

# %%
import sys
print(sys.executable)
# Out:
# /Users/Dayn1/opt/anaconda3/bin/python

# %%
# Out:
# Package                       Version              Latest      Type
# ----------------------------- -------------------- ----------- -----
# absl-py                       2.0.0                2.1.0       wheel
# alabaster                     0.7.12               0.7.16      wheel
# anyio                         3.5.0                4.3.0       wheel
# appnope                       0.1.2                0.1.4       wheel
# appscript                     1.1.2                1.2.5       wheel
# argon2-cffi                   21.3.0               23.1.0      wheel
# arrow                         1.2.2                1.3.0       wheel
# asgiref                       3.7.2                3.8.1       wheel
# astroid                       2.11.7               3.1.0       wheel
# astropy                       5.1                  6.0.1       wheel
# atomicwrites                  1.4.0                1.4.1       sdist
# attrs                         21.4.0               23.2.0      wheel
# ...
